# %%
cd /content/drive/MyDrive/GitHub/AI_API
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/GitHub/AI_API'
# /content

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
